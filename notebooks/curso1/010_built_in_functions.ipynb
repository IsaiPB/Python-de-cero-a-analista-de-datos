# %%
palabra = "Mundo"
print(f'Hola {palabra}')
# Out:
# Hola Mundo

# %%
len(palabra)
# Out:
# 5

# %%
type(palabra)
# Out:
# str

# %%
diccionario = {'a': 1, 'b': 2}

# %%
diccionario2 = dict()
type(diccionario2)
# Out:
# dict

# %%
bool()
# Out:
# False

# %%
bool(" ")
# Out:
# True

# %%
tupla = tuple()
type(tupla)
# Out:
# tuple

# %%
lista = list()
type(lista)
# Out:
# list

# %%
max(1, 2, 4)
# Out:
# 4

# %%
min(1, 3, 4)
# Out:
# 1

# %%
sum([1, 2, 3])
# Out:
# 6

# %%
range(10) # Rango de 0 a 10 iterable
# Out:
# range(0, 10)

# %%
range(2, 10, 2)
# Out:
# range(2, 10, 2)

# %%
# Saber en que posición esta un numero con range

for i in enumerate(range(3, 10, 2)):
    print(i)
# Out:
# (0, 3)
# (1, 5)
# (2, 7)
# (3, 9)

# %%
# convertir enumerate en elementos y quitar tupla en for

for i, j in enumerate(range(3, 10, 2)):
    print(i, j)
# Out:
# 0 3
# 1 5
# 2 7
# 3 9

# %%
abs(-2)
# Out:
# 2

# %%
int(2.834564)
# Out:
# 2

# %%
# Función para redondear

round(2.834327777, ndigits= 3)
# Out:
# 2.834

# %%
# Función ordenar elementos

sorted([1, 3, 2])
# Out:
# [1, 2, 3]

# %%
# Ordenar letras

sorted("Hola Mundo")
# Out:
# [' ', 'H', 'M', 'a', 'd', 'l', 'n', 'o', 'o', 'u']
